# %% [markdown]
# ### Why Seaborn?
#
# - provides a layer of abstraction hence simpler to use
# - better aesthetics
# - more graphs included

# %% [markdown]
# ### Seaborn Roadmap
#
# Types of Functions
#
# - Figure Level
# - Axis Level
#
# Main Classification
#
# - Relational Plot
# - Distribution Plot
# - Categorical Plot
# - Regression Plot
# - Matrix Plot
# - Multiplots
#
# https://seaborn.pydata.org/api.html

# %% [markdown]
# ### 1. Relational Plot
#
# - to see the statistical relation between 2 or more variables.
# - Bivariate Analysis
#
# Plots under this section
#
# - scatterplot
# - lineplot

# %% [markdown]
# #### Scatterplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px      # importing this only for a dataset

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# scatterplot (axis level function)
sns.scatterplot(data = tips, x = 'total_bill', y = 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# relplot (figure level function)
sns.relplot(data = tips, x = 'total_bill', y = 'tip', kind = 'scatter')
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# amazing features of seaborn
sns.relplot(data = tips, x = 'total_bill', y = 'tip', kind = 'scatter', hue = 'sex')
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = tips, x = 'total_bill', y = 'tip', kind = 'scatter',hue = 'sex', style = 'time')
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = tips, x = 'total_bill', y = 'tip', kind = 'scatter',hue = 'sex', style = 'time', size = 'size')
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### Lineplot

# %%
df = px.data.gapminder()  # importing dataset from plotly
df = df[ df['country'] == 'Bangladesh' ]
df
# Out:
#         country continent  year  lifeExp        pop    gdpPercap iso_alpha  \
# 96   Bangladesh      Asia  1952   37.484   46886859   684.244172       BGD
# 97   Bangladesh      Asia  1957   39.348   51365468   661.637458       BGD
# 98   Bangladesh      Asia  1962   41.216   56839289   686.341554       BGD
# 99   Bangladesh      Asia  1967   43.453   62821884   721.186086       BGD
# 100  Bangladesh      Asia  1972   45.252   70759295   630.233627       BGD
# 101  Bangladesh      Asia  1977   46.923   80428306   659.877232       BGD
# 102  Bangladesh      Asia  1982   50.009   93074406   676.981866       BGD
# 103  Bangladesh      Asia  1987   52.819  103764241   751.979403       BGD
# 104  Bangladesh      Asia  1992   56.018  113704579   837.810164       BGD
# 105  Bangladesh      Asia  1997   59.412  123315288   972.770035       BGD
# 106  Bangladesh      Asia  2002   62.013  135656790  1136.390430       BGD
# 107  Bangladesh      Asia  2007   64.062  150448339  1391.253792       BGD
#
#      iso_num
# 96        50
# 97        50
# 98        50
# 99        50
# 100       50
# 101       50
# 102       50
# 103       50
# 104       50
# 105       50
# 106       50
# 107       50

# %%
# lineplot (axis level function)
sns.lineplot(data = df, x = 'year', y = 'lifeExp')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
# relplot (figure level function)
sns.relplot(kind = 'line', data = df, x = 'year', y = 'lifeExp')
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df = px.data.gapminder()  # importing dataset from plotly
df = df[ df['country'].isin(['Bangladesh', 'India', 'Australia', 'Canada']) ]
df
# Out:
#         country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 60    Australia   Oceania  1952   69.120     8691212  10039.595640       AUS
# 61    Australia   Oceania  1957   70.330     9712569  10949.649590       AUS
# 62    Australia   Oceania  1962   70.930    10794968  12217.226860       AUS
# 63    Australia   Oceania  1967   71.100    11872264  14526.124650       AUS
# 64    Australia   Oceania  1972   71.930    13177000  16788.629480       AUS
# 707       India      Asia  2007   64.698  1110396331   2452.210407       IND
#
#      iso_num
# 60        36
# 61        36
# 62        36
# 63        36
# 64        36
# 65        36
# 66        36
# 67        36
# 68        36
# 69        36
# 70        36
# 71        36
# 96        50
# 97        50
# 98        50
# 99        50
# 100       50
# 101       50
# 102       50
# 103       50
# 104       50
# 105       50
# 106       50
# 107       50
# 240      124
# 241      124
# 242      124
# 243      124
# 244      124
# 245      124
# 246      124
# 247      124
# 248      124
# 249      124
# 250      124
# 251      124
# 696      356
# 697      356
# 698      356
# 699      356
# 700      356
# 701      356
# 702      356
# 703      356
# 704      356
# 705      356
# 706      356
# 707      356

# %%
# hue, style
sns.relplot(kind = 'line', data = df, x = 'year', y = 'lifeExp', hue = 'country', style = 'continent')
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# facetplot can be only used in figure level function
sns.relplot(kind = 'line', data = df, x = 'year', y = 'lifeExp', hue = 'country', style = 'continent', col = 'country', row = 'continent')
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# col_wrap
sns.relplot(kind = 'line', data = df, x = 'year', y = 'lifeExp', hue = 'country', style = 'continent', col = 'country', col_wrap = 2)
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 2. Distribution Plots
#
# - used for univariate analysis
# - used to find out the distribution
# - Range of the observation
# - Central Tendency
# - is the data bimodal?
# - Are there outliers?
#
# Plots under distribution plot
#
# - histplot
# - kdeplot
# - rugplot

# %% [markdown]
# #### Histplot

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# histplot (axis level function)
sns.histplot(data = tips, x = 'total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# displot (figure level function)
sns.displot(kind = 'hist', data = tips, x = 'total_bill')
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# bins parameter
sns.displot(kind = 'hist', data = tips, x = 'total_bill', bins = 5)
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# It’s also possible to visualize the distribution of a categorical variable using the logic of a histogram. 
# Discrete bins are automatically set for categorical variables

# but it is basically a count plot
sns.histplot(data = tips, x = 'day')
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
# hue
sns.displot(kind = 'hist', data = tips, x = 'total_bill', bins = 5, hue = 'sex')
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# faceting using col and row -> not work on histplot function
sns.displot(kind = 'hist', data = tips, x = 'total_bill', bins = 5, col = 'sex')
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# element
sns.displot(kind = 'hist', data = tips, x = 'total_bill', bins = 5, hue = 'sex', element = 'step')
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### KDEplot

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# kdeplot (axis level function)
sns.kdeplot(data = tips, x = 'total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# displot (figure level)
sns.displot(kind = 'kde', data = tips, x = 'total_bill')
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(kind = 'kde', data = tips, x = 'total_bill', hue = 'sex')
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(kind = 'kde', data = tips, x = 'total_bill', hue = 'sex', fill = True)
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(kind = 'kde', data = tips, x = 'total_bill', col = 'sex')
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### Rugplot

# %%
# Rugplot

# Plot marginal distributions by drawing ticks along the x and y axes.

# This function is intended to complement other plots by showing the location of individual observations in an unobtrusive way.
sns.displot(kind = 'kde', data = tips, x = 'total_bill')
sns.rugplot(data = tips, x = 'total_bill')
# Out:
# C:\Users\sadik\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# Bivariate histogram
# A bivariate histogram bins the data within rectangles that tile the plot 
# and then shows the count of observations within each rectangle with the fill color

sns.histplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Bivariate Kdeplot
# a bivariate KDE plot smoothes the (x, y) observations with a 2D Gaussian
sns.kdeplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 2. Matrix Plot
#
# - Heatmap
# - Clustermap

# %%
df = px.data.gapminder()
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
# ...       ...
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716
#
# [1704 rows x 8 columns]

# %%
# heatmap (axis level function)
temp_df = df.pivot(index = 'country', columns = 'year', values = 'lifeExp')
sns.heatmap(temp_df)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
temp_df = df[ df['continent'] == 'Asia' ].pivot(index = 'country', columns = 'year', values = 'lifeExp')
plt.figure(figsize=(15,15))
sns.heatmap(temp_df, cmap = 'summer', annot = True, linewidth = 1)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# Clustermap

# Plot a matrix dataset as a hierarchically-clustered heatmap.

# This function requires scipy to be available.

iris = px.data.iris()
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 145           3
# 146           3
# 147           3
# 148           3
# 149           3
#
# [150 rows x 6 columns]

# %%
sns.clustermap(iris.iloc[:,:4])
